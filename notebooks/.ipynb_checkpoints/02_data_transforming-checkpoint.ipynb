# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import scipy.stats as ss
# !pip install scikit-learn
import sklearn
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /home/luiz/desktop/UFPA/2026.2/lab_eng_software/Projeto_vale/.venv/lib/python3.14/site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in /home/luiz/desktop/UFPA/2026.2/lab_eng_software/Projeto_vale/.venv/lib/python3.14/site-packages (from scikit-learn) (1.17.1)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.9.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 4.3 MB/s  0:00:02a 0:00:010:00:01:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, narwhals, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# Successfully installed joblib-1.5.3 narwhals-2.22.1 scikit-learn-1.9.0 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pwd
# !ls
path = "/home/luiz/desktop/UFPA/2026.2/lab_eng_software/Projeto_vale/notebooks"
january = os.path.join(path, "jan_limpo.csv")
jan = pd.read_csv(january)
jan.head()
# Out:
# /home/luiz/desktop/UFPA/2026.2/lab_eng_software/Projeto_vale/notebooks
# 01_data_understanding.ipynb  head_janeiro.png  janeiro.pdf
# 02_data_transforming.ipynb   head_janeiro.svg  jan_limpo.csv
# /tmp/ipykernel_7856/2486672183.py:5: DtypeWarning: Columns (0: Valor) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan = pd.read_csv(january)
#                   Data_Evento             Inicio_Turno  \
# 0  2025-01-01 00:00:14.553000  2024-12-31 18:00:00.000
# 1  2025-01-01 00:00:14.553000  2024-12-31 18:00:00.000
# 2  2025-01-01 00:02:20.280000  2024-12-31 18:00:00.000
# 3  2025-01-01 00:02:59.077000  2024-12-31 18:00:00.000
# 4  2025-01-01 00:03:37.963000  2024-12-31 18:00:00.000
#
#                  Fim_Turno     TAG Tag_Frota      Tipo  \
# 0  2025-01-01 06:00:00.000  CA5926  793-D 5S  Caminhao
# 1  2025-01-01 06:00:00.000  CA5926  793-D 5S  Caminhao
# 2  2025-01-01 06:00:00.000  CA5926  793-D 5S  Caminhao
# 3  2025-01-01 06:00:00.000  CA5926  793-D 5S  Caminhao
# 4  2025-01-01 06:00:00.000  CA5926  793-D 5S  Caminhao
#
#   Matricula_Operador_Hash  Id_Alarme                               Alarme  \
# 0          H_7d2a33163e23  335609934  Rx Channel A Not Receiving Messages
# 1          H_7d2a33163e23  335609935  Rx Channel B Not Receiving Messages
# 2          H_7d2a33163e23   84626976                              Dipper
# 3          H_7d2a33163e23   84626976                              Dipper
# 4          H_7d2a33163e23   84626976                              Dipper
#
#    Id_Criticidade    Criticidade             Valor  Is_Dont_Go
# 0               3  Informacional                 0           0
# 1               3  Informacional                 0           0
# 2               3  Informacional  43,7999992370605           0
# 3               3  Informacional  74,7000045776367           0
# 4               3  Informacional  103,800003051758           0

# %% [markdown]
# Ajustando dados para cáculo de correlações

# %%
# 1. Corrigindo a coluna 'Valor' (trocando vírgula por ponto e convertendo para float)
jan['Valor'] = jan['Valor'].astype(str).str.replace(',', '.')
jan['Valor'] = pd.to_numeric(jan['Valor'], errors='coerce')

# 2. Preenchendo possíveis valores nulos (ajuste a estratégia conforme sua regra de negócio)
jan['Valor'] = jan['Valor'].fillna(0)

# %% [markdown]
# # Correlação para Variáveis Numéricas

# %%
# Selecionando colunas numéricas
cols_numericas = ['Valor', 'Id_Criticidade']

print("--- Correlação com Is_Dont_Go (Variáveis Numéricas) ---")
for col in cols_numericas:
    # pointbiserialr retorna a correlação e o p-value
    corr, p_value = ss.pointbiserialr(jan[col], jan['Is_Dont_Go'])
    print(f"{col}:")
    print(f"  Correlação: {corr:.4f}")
    print(f"  P-value: {p_value:.4e}\n")
# Out:
# --- Correlação com Is_Dont_Go (Variáveis Numéricas) ---
# Valor:
#   Correlação: -0.0018
#   P-value: 4.4048e-05
#
# Id_Criticidade:
#   Correlação: -0.2260
#   P-value: 0.0000e+00

# %% [markdown]
# # Correlação para variáveis categórigas

# %%
def cramers_v(x, y):
    """Calcula a estatística V de Cramér para variáveis categóricas."""
    confusion_matrix = pd.crosstab(x, y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

cols_categoricas = ['TAG', 'Tag_Frota', 'Tipo', 'Alarme', 'Criticidade']

print("--- Força de Associação com Is_Dont_Go (Variáveis Categóricas - Cramér's V) ---")
for col in cols_categoricas:
    # Ignorar valores nulos para o teste
    valid_idx = jan[col].notna() & jan['Is_Dont_Go'].notna()
    
    v = cramers_v(jan.loc[valid_idx, col], jan.loc[valid_idx, 'Is_Dont_Go'])
    print(f"{col}: {v:.4f}")
# Out:
# --- Força de Associação com Is_Dont_Go (Variáveis Categóricas - Cramér's V) ---
# TAG: 0.0929
# Tag_Frota: 0.0747
# Tipo: 0.0685
# Alarme: 0.5449
# Criticidade: 0.2524

# %% [markdown]
# # Tratamento de dados

# %% [markdown]
# Transformando valores categóricos em numéricos

# %%
from sklearn.preprocessing import LabelEncoder

# Instanciando o encoder
le = LabelEncoder()

# Selecionando colunas que são do tipo 'object' (texto)
colunas_texto = ['TAG', 'Tag_Frota', 'Tipo']

print("Convertendo variáveis categóricas para inteiros...")
for col in colunas_texto:
    # O LabelEncoder transforma cada categoria única em um número (0, 1, 2...)
    jan[col] = le.fit_transform(jan[col].astype(str))
    
jan.head(3)
# Out:
# Convertendo variáveis categóricas para inteiros...
#                   Data_Evento             Inicio_Turno  \
# 0  2025-01-01 00:00:14.553000  2024-12-31 18:00:00.000
# 1  2025-01-01 00:00:14.553000  2024-12-31 18:00:00.000
# 2  2025-01-01 00:02:20.280000  2024-12-31 18:00:00.000
#
#                  Fim_Turno  TAG  Tag_Frota  Tipo Matricula_Operador_Hash  \
# 0  2025-01-01 06:00:00.000    0          3     0          H_7d2a33163e23
# 1  2025-01-01 06:00:00.000    0          3     0          H_7d2a33163e23
# 2  2025-01-01 06:00:00.000    0          3     0          H_7d2a33163e23
#
#    Id_Alarme                               Alarme  Id_Criticidade  \
# 0  335609934  Rx Channel A Not Receiving Messages               3
# 1  335609935  Rx Channel B Not Receiving Messages               3
# 2   84626976                              Dipper                3
#
#      Criticidade      Valor  Is_Dont_Go
# 0  Informacional   0.000000           0
# 1  Informacional   0.000000           0
# 2  Informacional  43.799999           0

# %% [markdown]
# Removendo redundâncias de Alarme e Criticidade

# %%
# Removendo as colunas textuais redundantes
jan = jan.drop(columns=['Criticidade', 'Alarme'])

print("Colunas 'Criticidade' e 'Alarme' removidas com sucesso.")
# Out:
# Colunas 'Criticidade' e 'Alarme' removidas com sucesso.

# %% [markdown]
# Divisão dos turnos e criação do "Tempo Trabalhando"

# %%
# 1. Garantindo que as colunas são do tipo datetime
jan['Data_Evento'] = pd.to_datetime(jan['Data_Evento'])
jan['Inicio_Turno'] = pd.to_datetime(jan['Inicio_Turno'])

# 2. Criando o "Tempo Trabalhando" (em horas)
jan['Tempo_Trabalhando_Horas'] = (jan['Data_Evento'] - jan['Inicio_Turno']).dt.total_seconds() / 3600

# 3. Dividindo o dia em 6 períodos (blocos de 4 horas)
# Extraímos apenas a hora do evento (0 a 23)
horas = jan['Data_Evento'].dt.hour

# Definimos os limites (bins) e os rótulos
limites = [0, 4, 8, 12, 16, 20, 24]
rotulos = ['Noite 2', 'Manhã 1', 'Manhã 2', 'Tarde 1', 'Tarde 2', 'Noite 1']

# pd.cut classifica a hora dentro dos limites definidos
jan['Periodo_Dia'] = pd.cut(horas, bins=limites, labels=rotulos, right=False)

# (Opcional) Converter o período do dia para inteiros também, já que a LogReg precisa de números
jan['Periodo_Dia_Int'] = LabelEncoder().fit_transform(jan['Periodo_Dia'])

print("Atributos de tempo criados com sucesso.")
# Out:
# Atributos de tempo criados com sucesso.

# %% [markdown]
# Mapeamento do Hash

# %%
# Pegando todos os hashes únicos
operadores_unicos = jan['Matricula_Operador_Hash'].unique()

# Criando um dicionário: { 'hash_1': 0, 'hash_2': 1, ... }
dict_operadores = {hash_op: i for i, hash_op in enumerate(operadores_unicos)}

# Aplicando o mapeamento (substituindo o hash pelo número)
jan['Matricula_Operador_Hash'] = jan['Matricula_Operador_Hash'].map(dict_operadores)

print(f"Total de {len(dict_operadores)} operadores mapeados para IDs numéricos.")
# Out:
# Total de 301 operadores mapeados para IDs numéricos.

# %% [markdown]
# Normalização do atributo Valor

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Selecionamos apenas as variáveis contínuas que precisam ser escalonadas
colunas_para_escalonar = ['Valor', 'Tempo_Trabalhando_Horas']

# Aplicando a normalização
jan[colunas_para_escalonar] = scaler.fit_transform(jan[colunas_para_escalonar])

print("Dados normalizados. As colunas contínuas agora têm média 0 e desvio padrão 1.")
jan[colunas_para_escalonar].head()
# Out:
# Dados normalizados. As colunas contínuas agora têm média 0 e desvio padrão 1.
#       Valor  Tempo_Trabalhando_Horas
# 0 -0.158350                 0.000883
# 1 -0.158350                 0.000883
# 2  1.388878                 0.011237
# 3  2.480415                 0.014433
# 4  3.508368                 0.017635

# %% [markdown]
# # Iniciando regressão logística

# %% [markdown]
# Definindo variáveis

# %%
# Definindo as variáveis preditoras (X) e a variável alvo (y)
# Removemos colunas de data/hora, a coluna categórica 'Periodo_Dia' (já temos a 'Periodo_Dia_Int') e o alvo.
colunas_para_remover = ['Data_Evento', 'Inicio_Turno', 'Fim_Turno', 'Periodo_Dia', 'Is_Dont_Go']

X = jan.drop(columns=colunas_para_remover)
y = jan['Is_Dont_Go']

print(f"Formato de X: {X.shape}")
print(f"Formato de y: {y.shape}")
# Out:
# Formato de X: (5400002, 9)
# Formato de y: (5400002,)

# %% [markdown]
# Dividindo dados entre treino e teste

# %%
from sklearn.model_selection import train_test_split

# Dividindo 70% para treino e 30% para teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"Tamanho do Treino: {X_train.shape[0]} amostras")
print(f"Tamanho do Teste: {X_test.shape[0]} amostras")
# Out:
# Tamanho do Treino: 3780001 amostras
# Tamanho do Teste: 1620001 amostras

# %% [markdown]
# Treinamento usando regressão logística

# %%
from sklearn.linear_model import LogisticRegression

# Instanciando o modelo
# max_iter foi aumentado para garantir que o algoritmo convirja sem avisos de erro
modelo_lr = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# Treinando o modelo
modelo_lr.fit(X_train, y_train)

print("Modelo treinado com sucesso!")
# Out:
# Modelo treinado com sucesso!

# %% [markdown]
# Avaliação de resultados

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Fazendo previsões com os dados de teste
y_pred = modelo_lr.predict(X_test)

# Exibindo as métricas principais (Precision, Recall, F1-Score)
print("--- Relatório de Classificação ---")
print(classification_report(y_test, y_pred))

# Plotando a Matriz de Confusão para visualizar acertos e erros
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Go (0)", "Don't Go (1)"])

fig, ax = plt.subplots(figsize=(6, 6))
disp.plot(ax=ax, cmap='Blues')
plt.title("Matriz de Confusão - Regressão Logística")
plt.show()
# Out:
# --- Relatório de Classificação ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97   1619227
#            1       0.01      0.84      0.01       774
#
#     accuracy                           0.94   1620001
#    macro avg       0.50      0.89      0.49   1620001
# weighted avg       1.00      0.94      0.97   1620001

# %% [markdown]
# Peso das variáveis

# %%
# Criando um DataFrame com os coeficientes do modelo
importancias = pd.DataFrame({
    'Variavel': X.columns,
    'Coeficiente': modelo_lr.coef_[0]
})

# Ordenando pelos coeficientes de maior impacto absoluto
importancias['Impacto_Absoluto'] = importancias['Coeficiente'].abs()
importancias = importancias.sort_values(by='Impacto_Absoluto', ascending=False)

# Plotando os coeficientes
plt.figure(figsize=(10, 6))
sns.barplot(data=importancias, x='Coeficiente', y='Variavel', palette='viridis', hue='Variavel')
plt.title('Importância das Variáveis (Coeficientes da Regressão Logística)')
plt.xlabel('Peso (Impacto em Is_Dont_Go)')
plt.ylabel('Variáveis')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
