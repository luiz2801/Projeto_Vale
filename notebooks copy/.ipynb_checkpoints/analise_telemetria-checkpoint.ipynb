# %%
#pip install seaborn
# Out:
# Requirement already satisfied: seaborn in ./.venv/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.venv/lib/python3.14/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in ./.venv/lib/python3.14/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.venv/lib/python3.14/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
seed = 42

# %%
jan = pd.read_csv("janeiro.csv")
# feb = pd.read_csv("fevereiro.csv")
# mar = pd.read_csv("marco.csv")
# apr = pd.read_csv("abil.csv")
# may = pd.read_csv("maio.csv")
# jun = pd.read_csv("junho.csv")
# months = [jan, feb, mar, apr, may, jun]
# Out:
# /tmp/ipykernel_60942/1320863208.py:1: DtypeWarning: Columns (0: Valor, 1: Classe) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan = pd.read_csv("janeiro.csv")

# %%
# for i in months:
#     print(i.shape)
print(jan.shape)
jan.head()
# Out:
# (5400002, 18)
#    Id_Eventos_Telemetria                 Data_Evento             Inicio_Turno  \
# 0                9372078  2025-01-01 00:00:14.553000  2024-12-31 18:00:00.000
# 1                9372079  2025-01-01 00:00:14.553000  2024-12-31 18:00:00.000
# 2                9372097  2025-01-01 00:02:20.280000  2024-12-31 18:00:00.000
# 3                9372111  2025-01-01 00:02:59.077000  2024-12-31 18:00:00.000
# 4                9372120  2025-01-01 00:03:37.963000  2024-12-31 18:00:00.000
#
#                  Fim_Turno  Dia Localidade     TAG Tag_Frota      Tipo  \
# 0  2025-01-01 06:00:00.000    1    Itabira  CA5926  793-D 5S  Caminhao
# 1  2025-01-01 06:00:00.000    1    Itabira  CA5926  793-D 5S  Caminhao
# 2  2025-01-01 06:00:00.000    1    Itabira  CA5926  793-D 5S  Caminhao
# 3  2025-01-01 06:00:00.000    1    Itabira  CA5926  793-D 5S  Caminhao
# 4  2025-01-01 06:00:00.000    1    Itabira  CA5926  793-D 5S  Caminhao
#
#   Nome_Operador_Anon Matricula_Operador_Hash  Id_Alarme  \
# 0             OP_261          H_7d2a33163e23  335609934
# 1             OP_261          H_7d2a33163e23  335609935
# 2             OP_261          H_7d2a33163e23   84626976
# 3             OP_261          H_7d2a33163e23   84626976
# 4             OP_261          H_7d2a33163e23   84626976
#
#                                 Alarme  Id_Criticidade    Criticidade  \
# 0  Rx Channel A Not Receiving Messages               3  Informacional
# 1  Rx Channel B Not Receiving Messages               3  Informacional
# 2                              Dipper                3  Informacional
# 3                              Dipper                3  Informacional
# 4                              Dipper                3  Informacional
#
#               Valor Classe  Is_Dont_Go
# 0                 0    NaN           0
# 1                 0    NaN           0
# 2  43,7999992370605    NaN           0
# 3  74,7000045776367    NaN           0
# 4  103,800003051758    NaN           0

# %%
def show_missig_values(dataset):
    rows = dataset.shape[0]
    missing_counts = dataset.isnull().sum().reset_index()
    missing_counts.columns = ["coluna", "valores_faltantes"]
    
    print("Número de valores faltando.")
    for col, val in dataset.isnull().sum().items():
        print(f"{col}: {val} -> {val/rows*100:.2f}%")
    
    plt.figure(figsize=(12,6))
    sns.barplot(data=missing_counts, 
                x="coluna", 
                y="valores_faltantes",
                hue="coluna",
                palette="viridis",
                legend=False,
                dodge=False)
    
    plt.xticks(rotation=45, ha='right')
    plt.title("Valores Faltando por Coluna", fontsize=16)
    plt.xlabel("Colunas")
    plt.ylabel("Número de valores faltantando")
    plt.tight_layout()
    plt.show()
#for i in months:
#    show_missig_values(i)

# %%
# Dropping the Classe column 
for month in range(len(months)):
    months[month] = months[month].drop(columns="Classe")

# %%
for i in months:
    print(i.shape)
# Out:
# (5400002, 17)
# (5709935, 17)
# (5688538, 17)
# (6475045, 17)
# (6036291, 17)
# (7854243, 17)

# %%
def show_distribution(dataset, cut_columns=[], max_categories=50000):
    """
    Exibe a distribuição de colunas relevantes, filtrando IDs, 
    colunas constantes e alta cardinalidade.
    """
    for col in dataset.columns:
        # 1. Filtro de colunas ignoradas manualmente
        if col in cut_columns:
            continue
            
        # 2. Filtro de Variância: Ignora se a coluna tiver apenas 1 valor único (ex: Localidade "Itabira" em tudo)
        unique_count = dataset[col].nunique()
        if unique_count <= 1:
            continue
            
        # 3. Filtro de IDs/Alta Cardinalidade: Se for ID ou Hash (muitos valores únicos em relação ao total)
        # Se mais de 90% dos dados forem únicos, provavelmente é um ID/Chave Primária
        if unique_count > len(dataset) * 0.9:
            continue

        plt.figure(figsize=(10, 5))
        
        # Lógica para colunas NUMÉRICAS
        if pd.api.types.is_numeric_dtype(dataset[col]):
            plt.title(f"Distribuição Numérica: '{col}'", fontsize=12)
            sns.histplot(dataset[col], color="skyblue", bins=30, stat="density", kde=True)
            plt.ylabel("Densidade")
            
        # Lógica para colunas CATEGÓRICAS
        else:
            # Se tiver categorias demais (ex: nomes de operadores), pegamos apenas as Top X
            if unique_count > max_categories:
                data_to_plot = dataset[col].value_counts().head(max_categories)
                plt.title(f"Top {max_categories} Categorias: '{col}'", fontsize=12)
            else:
                data_to_plot = dataset[col].value_counts()
                plt.title(f"Distribuição Categórica: '{col}'", fontsize=12)

            sns.barplot(x=data_to_plot.index, y=data_to_plot.values, palette="viridis", hue=data_to_plot.index, legend=False)
            plt.xticks(rotation=45, ha="right")
            plt.ylabel("Frequência")

        plt.xlabel(col)
        plt.tight_layout()
        plt.show()

# %%
def particoes(month: pandas.series, n_chunks: int) -> list:
    chunk_size = len(month) // n_chunks
    
    
    return [month.iloc[i * chunk_size : (i + 1) * chunk_size] for i in range(n_chunks)]

# %%
partes = particoes(jan, 180)

print(partes[0])
# Out:
#        Id_Eventos_Telemetria                 Data_Evento  \
# 0                    9372078  2025-01-01 00:00:14.553000
# 1                    9372079  2025-01-01 00:00:14.553000
# 2                    9372097  2025-01-01 00:02:20.280000
# 3                    9372111  2025-01-01 00:02:59.077000
# 4                    9372120  2025-01-01 00:03:37.963000
# ...                      ...                         ...
# 29995               22923577  2025-01-31 00:13:53.397000
# 29996               22923580  2025-01-31 00:14:03.000000
# 29997               22923584  2025-01-31 00:14:04.550000
# 29998               22923587  2025-01-31 00:14:09.477000
# 29999               22923588  2025-01-31 00:14:11.217000
#
#                   Inicio_Turno                Fim_Turno  Dia Localidade  \
# 0      2024-12-31 18:00:00.000  2025-01-01 06:00:00.000    1    Itabira
# 1      2024-12-31 18:00:00.000  2025-01-01 06:00:00.000    1    Itabira
# 2      2024-12-31 18:00:00.000  2025-01-01 06:00:00.000    1    Itabira
# 3      2024-12-31 18:00:00.000  2025-01-01 06:00:00.000    1    Itabira
# 4      2024-12-31 18:00:00.000  2025-01-01 06:00:00.000    1    Itabira
# ...                        ...                      ...  ...        ...
# 29995  2025-01-30 18:00:00.000  2025-01-31 06:00:00.000   31    Itabira
# 29996  2025-01-30 18:00:00.000  2025-01-31 06:00:00.000   31    Itabira
# 29997  2025-01-30 18:00:00.000  2025-01-31 06:00:00.000   31    Itabira
# 29998  2025-01-30 18:00:00.000  2025-01-31 06:00:00.000   31    Itabira
# 29999  2025-01-30 18:00:00.000  2025-01-31 06:00:00.000   31    Itabira
#
#           TAG Tag_Frota      Tipo Nome_Operador_Anon Matricula_Operador_Hash  \
# 0      CA5926  793-D 5S  Caminhao             OP_261          H_7d2a33163e23
# 1      CA5926  793-D 5S  Caminhao             OP_261          H_7d2a33163e23
# 2      CA5926  793-D 5S  Caminhao             OP_261          H_7d2a33163e23
# 3      CA5926  793-D 5S  Caminhao             OP_261          H_7d2a33163e23
# 4      CA5926  793-D 5S  Caminhao             OP_261          H_7d2a33163e23
# ...       ...       ...       ...                ...                     ...
# 29995  CA5927  793-D 5S  Caminhao             OP_087          H_8b8cdb53a53e
# 29996  CA5927  793-D 5S  Caminhao             OP_087          H_8b8cdb53a53e
# 29997  CA5927  793-D 5S  Caminhao             OP_087          H_8b8cdb53a53e
# 29998  CA5927  793-D 5S  Caminhao             OP_087          H_8b8cdb53a53e
# 29999  CA5927  793-D 5S  Caminhao             OP_087          H_8b8cdb53a53e
#
#        Id_Alarme                               Alarme  Id_Criticidade  \
# 0      335609934  Rx Channel A Not Receiving Messages               3
# 1      335609935  Rx Channel B Not Receiving Messages               3
# 2       84626976                              Dipper                3
# 3       84626976                              Dipper                3
# 4       84626976                              Dipper                3
# ...          ...                                  ...             ...
# 29995   84608752      Engine Coolant Level - Inactive               3
# 29996   84608753        Engine Coolant Level - Active               2
# 29997   84608752      Engine Coolant Level - Inactive               3
# 29998   84608753        Engine Coolant Level - Active               2
# 29999   84608752      Engine Coolant Level - Inactive               3
#
#          Criticidade             Valor    Classe  Is_Dont_Go
# 0      Informacional                 0       NaN           0
# 1      Informacional                 0       NaN           0
# 2      Informacional  43,7999992370605       NaN           0
# 3      Informacional  74,7000045776367       NaN           0
# 4      Informacional  103,800003051758       NaN           0
# ...              ...               ...       ...         ...
# 29995  Informacional                 2  Inactive           0
# 29996    Não Crítico                 2  Activate           0
# 29997  Informacional                 2  Inactive           0
# 29998    Não Crítico                 2  Activate           0
# 29999  Informacional                 2  Inactive           0
#
# [30000 rows x 18 columns]

# %%
show_distribution(partes[0])

# %% [markdown]
# - Existem alarmes sem um valor correspondente, essas linhas podem ser descartadas?
# - Features como inicio do turno e fim do turno podem ser agrupados em categorias como manha1, manha2, tarde1, tarde2?
# - Classe tem 97% dos dados faltando, essa feature deve ser descartada?
# - Ids devem ser considerados categóricos?
# - O que eu devo fazer com alarme considerando que existem diversos tipos e é custoso visualizar todas as flags a olho nu?
# - Quais features eu posso remover sem prejuízo?
# - Posso agrupar diferentes tipos de "Alarme"? Se freio tem as possibilidades temperatura, pressão e auxiliar eu posso juntar tudo em freio ou devo separar em freio 1 para mais criticos e freios 2 para menos críticos?
# -

# %%
a = partes[0]["Alarme"].unique()
b = partes[0]["Criticidade"].unique()
a2 = partes[0]["Alarme"]
b2 = partes[0]["Criticidade"]
c = partes[0]["Is_Dont_Go"]
b
# Out:
# <StringArray>
# ['Informacional', 'Critico', 'Não Crítico']
# Length: 3, dtype: str

# %%
for i in a:
    print(i)
# Out:
# Rx Channel A Not Receiving Messages
# Rx Channel B Not Receiving Messages
# Dipper
# Load
# MC - QUEDA PRESSÃO DO ÓLEO MOTOR
# Body Up
# Cycle
# Oem Interface Timeout
# Oem Interface Normal
# Payload Overload - Active
# Payload Overload - Inactive
# Left Rear Brake Temperature - Active
# Right Rear Brake Temperature - Active
# Right Rear Brake Temperature - Inactive
# Left Rear Brake Temperature - Inactive
# Payload Overload Dump - Active
# Payload Overload Dump - Inactive
# OP - BAIXO NÍVEL DE COMBUSTÍVEL <20%
# 4th Tire Tag Timeout
# 5th Tire Tag Timeout
# 6th Tire Tag Timeout
# 2nd Tire Tag Timeout
# 3rd Tire Tag Timeout
# 1st Tire Tag Timeout
# Torque Converter Out Temperature - Active
# Torque Converter Out Temperature - Inactive
# Payload Overload Abuse - Active
# Payload Overload Abuse - Inactive
# High Steering Pressure - Active
# High Steering Pressure - Inactive
# 4th Tire Tag High Pressure change rate
# 6th Tire Tag High Pressure Change Rate
# 3rd Tire Tag High Pressure change rate
# Vims Brake Ecm - Active
# OEM Interface normal
# Left Front Brake Temperature - Active
# Right Front Brake Temperature - Active
# Vims Snapshot - Active
# Right Front Brake Temperature - Inactive
# Left Front Brake Temperature - Inactive
# 2nd Tire Tag High Pressure change rate
# MA - TEMPERATURA ARREF DO MOTOR >95C
# OEM Interface Timeout
# MC - QUEDA PRESSÃO DO ??LEO MOTOR
# Arc (Automatic Retarder Control) Ecm - Active
# Datalink Ibc (Integrated Braking Control) - Active
# Engine Ecm - Active
# Vims Transmission Ecm - Active
# TCS-Falha Sensor de Rotação da Roda TRAS ESQ
# Vims Transmission Ecm - Inactive
# Engine Ecm - Inactive
# Arc (Automatic Retarder Control) Ecm - Inactive
# Datalink Ibc (Integrated Braking Control) - Inactive
# Differential Pressure Low - Active
# Differential Pressure Low - Inactive
# Right Turbo In Pressure - Active
# Right Turbo In Pressure - Inactive
# Engine Oil  Level - Active
# Engine Oil  Level - Inactive
# 1st Tire Tag High Pressure Change Rate
# MA - BAIXA VOLTAGEM COM EQUIP. DESLIGADO <24V
# MC - Baixa Pressão de Ar de Freio <90psi
# Abusive Shift - Active
# Abusive Shift - Inactive
# 5th Tire Tag High Pressure Change Rate
# MC - BAIXA PRESSÃO DO ÓLEO MOTOR <240KPA
# TCS-Falha Sensor de Rotação da Roda TRAS DIR
# Engine Coolant Level - Active
# Engine Coolant Level - Inactive
# Aftercooler Level - Active
# Aftercooler Level - Inactive
# Cat Data Link (Active)
# Cat Data Link (Inactive)
# Right Exhaust Temperature - Active
# Right Exhaust Temperature - Inactive
# Vims Event List - Active
# Engine Prelube - Active
# Engine Prelube - Inactive
# Low Engine Coolant Temperature - Active
# Low Engine Coolant Temperature - Inactive
# Left Front Suspension Cylinder - Active
# Left Front Suspension Cylinder - Inactive
# Transmission Charge Filter - Active
# System Voltage - Active
# System Voltage - Inactive
# Right Front Suspension Cylinder - Active
# Right Front Suspension Cylinder - Inactive
# MA - Dif Temp Exaust > 60 ºC
# Parking Brake - Active
# Parking Brake - Inactive
# Transmission Oil Level - Active
# Transmission Oil Level - Inactive
# Final Drive Bypass Solenoid - Active
# Left Rear Suspension Cylinder - Active
# Body Up Ground Speed - Active
# Body Up Ground Speed - Inactive
# Brake Coolant Pump Solenoid - Active
# Brake Coolant Pump Solenoid - Inactive
# Engine Fan Solenoid - Active
# Engine Fan Solenoid - Inactive
# OP - FREIO RETARDO AUTO DESLIGADO
# Right Rear Suspension Cylinder - Active
# Right Rear Suspension Cylinder - Inactive
# Left Rear Suspension Cylinder - Inactive
# MA - Diferenca de Temperatura de Freio TE\/TD >25 °C
# Vims Brake Ecm - Inactive
# Fuel Level - Active
# Fuel Level - Inactive
# Brake\/Air Pressure - Active
# Brake\/Air Pressure - Inactive
# Differential Lube Pressure - Active
# Differential Lube Pressure - Inactive
# Torque Converter Filter - Active
# Torque Converter Filter - Inactive
# Transmission Charge Filter - Inactive
# Left Exhaust Temperature - Active
# Left Exhaust Temperature - Inactive
# Brake Stroke - Active
# Brake Stroke - Inactive

# %%
total = 0
casos = 0
for i in zip(b2, c):
    if i[0] == "Critico":
        total = total + 1
    if i[0] == "Critico" and i[1] == 1:
        casos = casos + 1
casos/total
# Out:
# 0.13458262350936967

# %% [markdown]
# 13% dos casos críticos gera um dont go?
# O que isso quer dizer, será que essa feature está correta ou eu estou interpretando errado?

# %%
def classificar_alarme_detalhado(nome_alarme):
    alarme = str(nome_alarme).upper()
    
    # ---------------------------------------------------------
    # 1. IDENTIFICAÇÃO DA SEVERIDADE (1 ou 2)
    # ---------------------------------------------------------
    # Palavras que indicam falha crítica, impacto direto ou parada
    criticos = ['MC -', 'MA -', 'ACTIVE', 'QUEDA', 'BAIXA PRESSÃO', 'FALHA', 'LOW PRESSURE', '>']
    
    # Palavras que indicam aviso, timeout, inatividade ou operação
    avisos = ['OP -', 'INACTIVE', 'TIMEOUT', 'NORMAL', 'CHANGE RATE', 'ABUSE', 'DUMP', 'LEVEL']
    
    # Define a severidade inicial
    severidade = "1" # Padrão é 1 (Aviso/Menos grave)
    if any(c in alarme for c in criticos) and not any(a in alarme for a in ['INACTIVE', 'NORMAL']):
        severidade = "2" # Se for crítico e NÃO estiver inativo/normal, vira 2

    # ---------------------------------------------------------
    # 2. IDENTIFICAÇÃO DO SISTEMA
    # ---------------------------------------------------------
    sistema = "Outros" # Categoria padrão se não achar nenhuma
    
    # Dicionário de sistemas e suas palavras-chave
    regras_sistemas = {
        "Motor": ['ENGINE', 'COOLANT', 'OIL', 'AFTERCOOLER', 'TURBO', 'EXHAUST', 'ARREF', 'COMBUSTÍVEL', 'PRELUBE', 'FAN'],
        "Freio": ['BRAKE', 'FREIO', 'IBC', 'ARC', 'RETARDO', 'PARKING'],
        "Transmissao": ['TRANSMISSION', 'TORQUE CONVERTER', 'SHIFT', 'DIFFERENTIAL', 'FINAL DRIVE', 'MARCHA'],
        "Suspensao_Lataria": ['SUSPENSION', 'STEERING', 'DIREÇÃO', 'CHASSIS'],
        "Pneu": ['TIRE', 'PNEU'],
        "Carga": ['PAYLOAD', 'DIPPER', 'LOAD', 'CYCLE', 'BODY UP'],
        "Eletronica": ['ECM', 'DATA LINK', 'VIMS', 'CHANNEL', 'OEM', 'VOLTAGEM', 'VOLTAGE', 'SENSOR']
    }
    
    # Busca qual sistema o alarme pertence
    for chave_sistema, palavras_chave in regras_sistemas.items():
        if any(palavra in alarme for palavra in palavras_chave):
            sistema = chave_sistema
            break # Achou o sistema, para de procurar
            
    # ---------------------------------------------------------
    # 3. RETORNA A COMBINAÇÃO (Ex: Freio2, Motor1, Pneu1)
    # ---------------------------------------------------------
    return f"{sistema}{severidade}"

# %%
novo = []
for alarme in partes[0]["Alarme"]:
    novo.append(classificar_alarme_detalhado(alarme))
novo
#classificar_alarme(partes[0]["Alarme"])
# Out:
# ['Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Freio2',
#  'Freio2',
#  'Freio1',
#  'Freio1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Motor1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Outros2',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Outros2',
#  'Carga1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Outros2',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Outros2',
#  'Carga1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Outros2',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Outros2',
#  'Outros2',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Outros2',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Transmissao2',
#  'Transmissao2',
#  'Transmissao1',
#  'Transmissao2',
#  'Transmissao1',
#  'Transmissao1',
#  'Carga1',
#  'Transmissao2',
#  'Carga1',
#  'Transmissao1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga2',
#  'Suspensao_Lataria2',
#  'Suspensao_Lataria1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Pneu1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Outros2',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Pneu1',
#  'Eletronica1',
#  'Eletronica1',
#  'Pneu1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Pneu1',
#  'Eletronica1',
#  'Eletronica1',
#  'Motor1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Outros2',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Outros2',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Pneu1',
#  'Eletronica1',
#  'Eletronica1',
#  'Pneu1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Pneu1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Outros2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga2',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Carga1',
#  'Carga1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Eletronica1',
#  'Outros2',
#  ...]

# %% [markdown]
# Posso agrupar avisos operacionais e não criticos?
