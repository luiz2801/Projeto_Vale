# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Lambda, Embedding, Concatenate, LSTM, Dense, BatchNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils.class_weight import compute_class_weight

# %%
# Verifica quais dispositivos estão disponíveis
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print(f"GPU detectada! O modelo vai voar 🚀: {gpus}")
else:
    print("Ainda usando CPU 🐢. Verifique a configuração do ambiente.")
# Out:
# Ainda usando CPU 🐢. Verifique a configuração do ambiente.

# %%
print("Carregando os dados temporais...")
# Certifique-se de que os dados estão ordenados temporalmente antes de tudo!
# df = df.sort_values(['TAG', 'Data_Evento']) 
df = pd.read_csv('dados_lstm.csv')
colunas_target = [col for col in df.columns if 'target' in col.lower()]
print("Colunas de Target encontradas:", colunas_target)
print(df.columns.tolist())
# 1. Tratamento de Categóricas (O LabelEncoder pode ser aplicado em todo o dataset 
# para mapear o vocabulário, desde que não vaze informações estatísticas do target)
le_alarme = LabelEncoder()
le_operador = LabelEncoder()
df['Id_Alarme'] = le_alarme.fit_transform(df['Id_Alarme'])
df['Matricula_Operador_Hash'] = le_operador.fit_transform(df['Matricula_Operador_Hash'])

# Salvando o tamanho do vocabulário para as camadas de Embedding
VOCAB_ALARME = df['Id_Alarme'].max() + 1
VOCAB_OPERADOR = df['Matricula_Operador_Hash'].max() + 1

# 2. Separação Cronológica de Treino (80%) e Teste (20%) agrupada por TAG
print("Realizando Split Cronológico por TAG...")
train_list, test_list = [], []

for tag, group in tqdm(df.groupby('TAG'), desc="Splitting"):
    # Split de 80% preservando a ordem do tempo
    split_idx = int(len(group) * 0.8)
    train_list.append(group.iloc[:split_idx])
    test_list.append(group.iloc[split_idx:])

df_train = pd.concat(train_list)
df_test = pd.concat(test_list)

# 3. Padronização 
# O fit_transform ocorre APENAS no treino. O test recebe apenas transform.
print("Aplicando StandardScaler (Fit no Treino, Transform no Teste)...")
scaler = StandardScaler()
cols_to_scale = ['Valor', 'Tempo_Trabalhando_Horas']

df_train.loc[:, cols_to_scale] = scaler.fit_transform(df_train[cols_to_scale])
df_test.loc[:, cols_to_scale] = scaler.transform(df_test[cols_to_scale])

# 4. Configurações da Janela Temporal
cols_features = [
    'Tag_Frota', 'Tipo', 'Matricula_Operador_Hash', 'Id_Alarme', 'Id_Criticidade', 
    'Valor', 'Tempo_Trabalhando_Horas', 'Periodo_Dia_Int', 
    'Dia_1', 'Dia_2', 'Dia_3', 'Dia_4', 'Dia_5', 'Dia_6'
]
SEQ_LENGTH = 30
PROBABILIDADE_MANTER_ZERO = 0.30  # Ajustado para manter 30% no treino
# Out:
# Carregando os dados temporais...
# Colunas de Target encontradas: []
# ['Data_Evento', 'TAG', 'Tag_Frota', 'Tipo', 'Matricula_Operador_Hash', 'Id_Alarme', 'Id_Criticidade', 'Valor', 'Tempo_Trabalhando_Horas', 'Periodo_Dia_Int', 'Dia_1', 'Dia_2', 'Dia_3', 'Dia_4', 'Dia_5', 'Dia_6', 'Is_Dont_Go']
# Realizando Split Cronológico por TAG...
# Splitting: 100%|██████████| 32/32 [00:00<00:00, 1675.04it/s]
# Aplicando StandardScaler (Fit no Treino, Transform no Teste)...

# %%
def criar_tensores(df_subset, is_train=True):
    X_list, y_list = [], []
    
    for tag, group in tqdm(df_subset.groupby('TAG'), desc=f"Gerando janelas ({'Treino' if is_train else 'Teste'})"):
        X_group = group[cols_features].values
        y_group = group['Is_Dont_Go'].values
        
        if len(X_group) < SEQ_LENGTH:
            continue
            
        for i in range(len(X_group) - SEQ_LENGTH):
            target = y_group[i + SEQ_LENGTH - 1]
            
            # Sub-amostragem da classe majoritária APENAS no conjunto de treinamento
            if is_train and target == 0 and np.random.rand() > PROBABILIDADE_MANTER_ZERO:
                continue
                
            janela = X_group[i : i + SEQ_LENGTH]
            X_list.append(janela)
            y_list.append(target)
            
    return np.array(X_list, dtype=np.float32), np.array(y_list, dtype=np.int8)

# Gerando os Tensores Finais
print("\nGerando tensores de Treino...")
X_train, y_train = criar_tensores(df_train, is_train=True)

print("\nGerando tensores de Teste...")
X_test, y_test = criar_tensores(df_test, is_train=False)

print("\n--- RESUMO DOS TENSORES ---")
print(f"Treino X: {X_train.shape} | Y: {y_train.shape} | % Classe 1: {(y_train.mean()*100):.2f}%")
print(f"Teste  X: {X_test.shape}  | Y: {y_test.shape}  | % Classe 1: {(y_test.mean()*100):.2f}%")

# Salvando
np.save('X_train.npy', X_train)
np.save('y_train.npy', y_train)
np.save('X_test.npy', X_test)
np.save('y_test.npy', y_test)
print("Tensores isolados e salvos com sucesso!")
# Out:
# Gerando tensores de Treino...
# Gerando janelas (Treino): 100%|██████████| 32/32 [00:01<00:00, 29.47it/s]
# Gerando tensores de Teste...
# Gerando janelas (Teste): 100%|██████████| 32/32 [00:00<00:00, 187.73it/s]
# --- RESUMO DOS TENSORES ---
# Treino X: (1296332, 30, 14) | Y: (1296332,) | % Classe 1: 0.15%
# Teste  X: (1079059, 30, 14)  | Y: (1079059,)  | % Classe 1: 0.06%
# Tensores isolados e salvos com sucesso!

# %%
# 1. Calculando pesos das classes para lidar com o desbalanceamento no treino
pesos = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(pesos))
print(f"Pesos das Classes: {class_weights}")

# 2. Definição da Entrada
# Formato: (Passos no Tempo = 30, Atributos = 14)
input_layer = Input(shape=(SEQ_LENGTH, 14), name="Input_Completo")

# 3. Funções de Fatiamento (Slicing) para as camadas Lambda
# O índice das colunas segue a lista: 
# 2 = Matricula_Operador_Hash | 3 = Id_Alarme
def slice_operador(x): return x[:, :, 2]
def slice_alarme(x): return x[:, :, 3]

def slice_numericos_e_restante(x):
    # Pega índices 0, 1 (Tag, Tipo) e 4 a 13 (Id_Criticidade até Dia_6)
    part_1 = x[:, :, 0:2]
    part_2 = x[:, :, 4:14]
    return tf.concat([part_1, part_2], axis=-1)

# Aplicando as fatias
operador_input = Lambda(slice_operador, name="Slice_Operador")(input_layer)
alarme_input = Lambda(slice_alarme, name="Slice_Alarme")(input_layer)
numericos_input = Lambda(slice_numericos_e_restante, name="Slice_Numericos")(input_layer)

# 4. Camadas de Embedding (Ajuste o output_dim conforme sua necessidade)
EMB_DIM = 8 
emb_operador = Embedding(input_dim=VOCAB_OPERADOR, output_dim=EMB_DIM, name="Emb_Operador")(operador_input)
emb_alarme = Embedding(input_dim=VOCAB_ALARME, output_dim=EMB_DIM, name="Emb_Alarme")(alarme_input)

# 5. Concatenação de todas as features em cada passo de tempo
# As saídas do embedding terão shape (Batch, 30, 8), e a parte numérica (Batch, 30, 12)
concat_layer = Concatenate(axis=-1, name="Concat_Features")([numericos_input, emb_operador, emb_alarme])

# 6. Arquitetura LSTM Profunda
lstm_1 = LSTM(64, return_sequences=True, name="LSTM_1")(concat_layer)
bn_1 = BatchNormalization(name="BatchNorm_1")(lstm_1)
drop_1 = Dropout(0.3, name="Drop_1")(bn_1)

lstm_2 = LSTM(32, return_sequences=False, name="LSTM_2")(drop_1)
bn_2 = BatchNormalization(name="BatchNorm_2")(lstm_2)
drop_2 = Dropout(0.3, name="Drop_2")(bn_2)

# 7. Camada de Saída (Classificação Binária)
output_layer = Dense(1, activation='sigmoid', name="Saida_Classificacao")(drop_2)

# Construindo o Modelo
model = Model(inputs=input_layer, outputs=output_layer)

# 8. Definição de Métricas e Compilação
metricas = [
    tf.keras.metrics.AUC(name='auc_roc'),
    tf.keras.metrics.AUC(curve='PR', name='auc_pr'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.Precision(name='precision')
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=metricas
)

model.summary()

# 9. Configurando Early Stopping para evitar Overfitting
early_stopping = EarlyStopping(
    monitor='val_auc_pr', # Focando no PR-AUC devido ao desbalanceamento
    mode='max',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# 10. Treinamento
print("\nIniciando o treinamento da rede LSTM...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    batch_size=256,
    class_weight=class_weights, # Lida com o desbalanceamento
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Pesos das Classes: {0: np.float64(0.5007462917181705), 1: np.float64(335.4896480331263)}
# E0000 00:00:1782148204.760831    6870 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1782148204.761029    7084 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1782148204.782672    6870 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Input_Completo      │ (None, 30, 14)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Slice_Operador      │ (None, 30)        │          0 │ Input_Completo[0… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Slice_Alarme        │ (None, 30)        │          0 │ Input_Completo[0… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Slice_Numericos     │ (None, 30, 12)    │          0 │ Input_Completo[0… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Emb_Operador        │ (None, 30, 8)     │      2,408 │ Slice_Operador[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Emb_Alarme          │ (None, 30, 8)     │      6,608 │ Slice_Alarme[0][… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Concat_Features     │ (None, 30, 28)    │          0 │ Slice_Numericos[… │
# │ (Concatenate)       │                   │            │ Emb_Operador[0][… │
# │                     │                   │            │ Emb_Alarme[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ LSTM_1 (LSTM)       │ (None, 30, 64)    │     23,808 │ Concat_Features[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNorm_1         │ (None, 30, 64)    │        256 │ LSTM_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Drop_1 (Dropout)    │ (None, 30, 64)    │          0 │ BatchNorm_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ LSTM_2 (LSTM)       │ (None, 32)        │     12,416 │ Drop_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNorm_2         │ (None, 32)        │        128 │ LSTM_2[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Drop_2 (Dropout)    │ (None, 32)        │          0 │ BatchNorm_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Saida_Classificacao │ (None, 1)         │         33 │ Drop_2[0][0]      │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 45,657 (178.35 KB)
#  Trainable params: 45,465 (177.60 KB)
#  Non-trainable params: 192 (768.00 B)
# Iniciando o treinamento da rede LSTM...
# Epoch 1/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 72s 14ms/step - auc_pr: 0.2441 - auc_roc: 0.9956 - loss: 0.0795 - precision: 0.0423 - recall: 0.9876 - val_auc_pr: 0.1454 - val_auc_roc: 0.9982 - val_loss: 0.0254 - val_precision: 0.1145 - val_recall: 0.9953
# Epoch 2/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 70s 14ms/step - auc_pr: 0.3679 - auc_roc: 0.9987 - loss: 0.0121 - precision: 0.3362 - recall: 1.0000 - val_auc_pr: 0.1254 - val_auc_roc: 0.9979 - val_loss: 0.0305 - val_precision: 0.1104 - val_recall: 1.0000
# Epoch 3/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 70s 14ms/step - auc_pr: 0.3802 - auc_roc: 0.9988 - loss: 0.0110 - precision: 0.3465 - recall: 1.0000 - val_auc_pr: 0.1486 - val_auc_roc: 0.9982 - val_loss: 0.0251 - val_precision: 0.0990 - val_recall: 0.9844
# Epoch 4/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 70s 14ms/step - auc_pr: 0.3822 - auc_roc: 0.9988 - loss: 0.0128 - precision: 0.3407 - recall: 0.9990 - val_auc_pr: 0.1469 - val_auc_roc: 0.9982 - val_loss: 0.0255 - val_precision: 0.1035 - val_recall: 0.9969
# Epoch 5/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 70s 14ms/step - auc_pr: 0.3905 - auc_roc: 0.9988 - loss: 0.0112 - precision: 0.3506 - recall: 0.9995 - val_auc_pr: 0.1160 - val_auc_roc: 0.9977 - val_loss: 0.0388 - val_precision: 0.0949 - val_recall: 1.0000
# Epoch 6/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 70s 14ms/step - auc_pr: 0.3885 - auc_roc: 0.9988 - loss: 0.0110 - precision: 0.3588 - recall: 1.0000 - val_auc_pr: 0.1136 - val_auc_roc: 0.9976 - val_loss: 0.0342 - val_precision: 0.0929 - val_recall: 1.0000
# Epoch 7/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 71s 14ms/step - auc_pr: 0.3829 - auc_roc: 0.9988 - loss: 0.0109 - precision: 0.3596 - recall: 1.0000 - val_auc_pr: 0.1015 - val_auc_roc: 0.9974 - val_loss: 0.0354 - val_precision: 0.0955 - val_recall: 1.0000
# Epoch 8/30
# 5064/5064 ━━━━━━━━━━━━━━━━━━━━ 70s 14ms/step - auc_pr: 0.3919 - auc_roc: 0.9988 - loss: 0.0104 - precision: 0.3590 - recall: 1.0000 - val_auc_pr: 0.1380 - val_auc_roc: 0.9981 - val_loss: 0.0313 - val_precision: 0.0915 - val_recall: 0.9984
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.

# %%
import matplotlib.pyplot as plt

def plotar_resultados_lstm(history):
    # Lista de métricas base obtidas do dicionário de histórico
    metricas_base = ['loss', 'auc_roc', 'auc_pr', 'precision', 'recall']
    nomes_metricas = ['Loss (Entropia Binária)', 'AUC-ROC', 'AUC-PR (Foco)', 'Precisão', 'Recall']
    
    epochs = range(1, len(history.history['loss']) + 1)
    
    # Criando subplots de forma limpa sem usar .figure()
    fig, axes = plt.subplots(3, 2, figsize=(14, 16))
    axes = axes.flatten()
    
    for i, (metric, nome) in enumerate(zip(metricas_base, nomes_metricas)):
        ax = axes[i]
        # Plot do Treino e Validação
        ax.plot(epochs, history.history[metric], 'b-o', label=f'Treino ({metric})')
        ax.plot(epochs, history.history[f'val_{metric}'], 'r-o', label=f'Validação (val_{metric})')
        
        # Linha vertical indicando a melhor época restaurada (Época 3)
        ax.axvline(x=3, color='g', linestyle='--', alpha=0.7, label='Melhor Época (Restaurada)')
        
        ax.set_title(f'Evolução de {nome}')
        ax.set_xlabel('Época')
        ax.set_ylabel(nome)
        ax.grid(True)
        ax.legend()
        
    # Desativa o último eixo que fica em branco (3x2 resulta em 6 subplots para 5 métricas)
    axes[5].axis('off')
    
    plt.tight_layout()
    plt.show()

# Para rodar no seu notebook, basta chamar a função passando o histórico do seu fit:
# plotar_resultados_lstm(history)
